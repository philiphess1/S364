# %% [markdown]
# ### Checkpoint2

# %% [markdown]
# Match the left to the right of the following
# Correct!
# An operator, denoted with a percent sign (%), that works on numbers and yields the remainder when one number is divided by another. What is the operator called?
# modulus
# Correct!
# A line of code that represents a command or action. For example, assign a liternal to a variable or print out a message using the print() function. What is the line of code called?.
# statement
# Correct!
# A type that represents numbers with fractional parts.
# floating point
# Correct!
# What is the type of a statement that stores a value to a variable?
# assignment
#
# Which of the following operator in Python joins strings together? For example: "Hello " operator "World!" result in "Hello World!"
#   *
# Correct!
#   +
#   &
#   concat
#
# What data type does the value 5.3 have? (the answer must be exact as in Jupyter notebook to receive points)
# Correct!
# float
# Correct Answers
# <class 'float'>
# float
#
# When executing the following code, what error would be raised? (Be as precise as possible)
#
# x = 4
# x + "USA"
# Correct!
#   TypeError, because x is an integer and "USA" is a string. The data types are different
#   NameError, because "USA" does not have a name
#   NameError, because the result of x + "USA" does not have a name
#   TypeError, because x is a variable and "USA" is a string. The data types are different
#
# What are the reasons to use comments in code? Select ALL correct answers.
# Correct!
#   Provide information such as the author, version, date of the code
# Correct!
#   Hide some code from the interpreter so they won't be executed
#   Give official authority to the code
# Correct!
#   Describe or explain the code logic
#
# What do you get when you run the code: (answers must be exact to earn points. If an error is raised, provide only the error name - the red text on the first line. Remember Python is case sensitive.
#
# int(True)
# 1
# int(False)
# 0
# int(None)
# TypeError
# Answer 1:
# Correct!1
# Answer 2:
# Correct!0
# Answer 3:
# Correct!TypeError
#
# Which of the following is NOT true about if statement?
#   if statement is used to implement one kind of conditional flow
#   an if statement must have a condition
# Correct!
#   an if statement must be matched with an else branch
#   The code blocks in the branches must be indented.
#
#    school has following rules for grading system:
#
# Below 25 - F
# 25 to 45 - E
# 46 to 50 - D
# 51 to 60 - C
# 61 to 80 - B
# Above 80 - A
# Which of the following is an INCORRECT implementation?
#
# Correct Answer
#
# if marks<25:
#   print ("F")
# elif marks>=25 and marks<45:
#   print("E")
# elif marks>=46 and marks<50:
#   print("D")
# elif marks>=51 and marks<60:
#   print("C")
# elif marks>=61 and marks<=80:
#   print("B")
# else:
#   print("A")
#
# You have 3 people's age stored in 3 variables first, second and third. If their ages are all different, will the following statement find find the oldest age properly?
#
#
# [ Select ]
#  :
#
# if first > second and first > third:
#     print("Oldest age is", first)
# elif second > first and second > third:
#     print("Oldest age is", second)
# else:
#     print("Oldest age is", third)
#
# [ Select ]
#  :
#
# if first > second and second > third:
#     print("Oldest age is",first)
# elif second > first and first > third:
#     print("Oldest age is",second)
# elif third > first and first > second:
#     print("Oldest age is",third)
# else:
#     print("Cannot tell")
#
# [ Select ]
#
# if first > second or first > third:
#   print("Oldest age is",first)
# elif second > first or second > third:
#   print("Oldest age is",second)
# else:
#   print("Oldest age is",third)
#
#
# Answer 1:
# Correct!
# Yes
# Answer 2:
# Correct!
# No
# Answer 3:
# Correct!
# No
#
# When you use the input() function to get the income of the user's, what data type is the value returned?
#   float or floating points
#   boolean or bool
# Correct!
#   string or str
#   integer or int

# %% [markdown]
# ### Checkpoint3
#
# Which of the following situations are good candidates to be handled in a try/except structure? Select True if it is.
#
# Might misspell the name of the function called False
# Missing colon (:) after the for loop header
# [ Select ]
# Ask the user to enter a number which will be converted to a float in the program
# [ Select ]
# Try to open a file with a user provided file path
# [ Select ]
#
# Answer 1:
# Correct!
# False
# Answer 2:
# Correct!
# False
# Answer 3:
# Correct!
# True
# Answer 4:
# Correct!
# True
#
# Question 2
# 0.8 / 1 pts
# Match the control flows on the left to the descriptions on the right
# You Answered
# Sequential
# What to do when code execution is completed.
#
# execute the code line by line in the order it is written. This this the default execution flow
# Correct!
# Conditional
# At a decision point, the code execution could go through different branches that are mutually exclusive
# Correct!
# Loop
# Execute certain code repeatedly for multiple number of times based on a condition
# Correct!
# Function
# Pre-defined code module executed when needed
# Correct!
# Exception Handling
# Purposefully designed code executed when unexpected problems occur in normal execution
# Other Incorrect Match Options:
# What to do when code execution is completed.
#
# Question 3
# 1 / 1 pts
# What is the result of the following code:
#
# num = 3
# while num > 0:
#     print(num)
#     num = num - 1
#
# 3 2 1
#
# 2
# 1
# 0
#
# 2 1 0
# Correct!
#
# 3
# 2
# 1
#
# Question 4
# 1 / 1 pts
# What is the result of the following code:
#
# num = 3
# while num > 0:
#     print(num)
#
# 3
# 2
# 1
#
# 3
# 3
# 3
#
# 2
# 1
# 0
# Correct!
#
# 3
# 3
# 3
# ... won't stop
#
# Question 5
# 1 / 1 pts
# What will happen immediately if the user types in "Secret"?
#
# password = input("Please enter your password\n")
# while password != 'secret':
#     print("Try again")
#     password = input()
# print("Welcome!")
# Correct!
#   Try again
#   Welcome!
#   There will be an error message
#   Please enter your password
#
# Question 6
# 1 / 1 pts
# Take a look at the following code:
#
# for i in range(1, 7, 3):
#     print("Hello world!")
# How many times Hello world! will be printed out?
#
# Correct!
#   2
#   7
#   3
#   1
#
# Question 7
# 1 / 1 pts
# Take a look at the following code:
#
# for i in range(1, 7, -3):
#     print("Hello world!")
# How many times Hello world! will be printed out?
#
#   2
#   3
# Correct!
#   0
#   1
#
#
# What will lead to an infinte loop?
#
#
# When a programmer does not explicitly change the target variable (counter) inside a for loop
#
#   When the condition in the while loop header never becomes true
# Correct!
#   When a programmer does not explicitely change the counter variable (if one is used) inside a while loop
# Correct!
#   When the condition in the while loop header never becomes false
#
# Question 9
# 1 / 1 pts
# The following sentences try to describe the control flow of try/except structure. Select whether they are correct or incorrect ?
#
# Program always executes the code inside try block first, then the code inside except block and execution continues after the try/except structure
# [ Select ]
# When the code executes without any exception, the code block inside try is executed and code block inside except is skipped and program continues after the try/except structure Correct
# When the code execution encounters an exception, the code inside the try block after the line of code that encounters the error is skipped, code inside the except block is executed and programs continues after the try/except structure Correct
# When the code execution encounters an exception, the code block inside try is skipped, code inside the except block is executed and programs stops execution after the except block completes.
# [ Select ]
# Answer 1:
# Correct!
# Incorrect
# Answer 2:
# Correct!
# Correct
# Answer 3:
# Correct!
# Correct
# Answer 4:
# Correct!
# Incorrect
#
# Question 10
# 0 / 1 pts
# Which of the following statements are correct about loops? Select ALL CORRECT ones.
#   A continue statement inside a loop will exit out of the loop when executed
# Correct!
#   A break statement inside a loop will exit out of the loop when executed
# You Answered
#   A while loop can be easily written as a for loop but not the other way around
# It is not that easy to convert some while loops into for loops.
# Correct Answer
#   A for loop can be easily written as a while loop but not the other way around

# %% [markdown]
# ### Checkpoint4
#
# Question 1
# 2 / 2 pts
# Match the following terms to their definition...
# Correct!
# function definition
# A statement that creates a new function, specifying its name, parameters, and the code block in it.
# Correct!
# dot notation
# The syntax for calling a function in another module by specifying the module name followed by a dot (period) and the function name.
# Correct!
# return value
# The result of a function passed back to the caller
# Correct!
# void function
# A function that does not return a value.
# Correct!
# import statement
# A statement that reads a module file and make the module functions available
# Correct!
# function call
# A statement that executes a function. It consists of the function name followed by an argument list in ()
# Correct!
# argument
# A value provided to a function when the function is called. This value is assigned to the corresponding parameter in the function.
# Correct!
# parameter
# A variable used inside a function to hold the value passed in as an argument.
#
# Question 2
# 1 / 1 pts
# Which keyword indicates the start of the function definition?
#   while
#   try
#   func
# Correct!
#   def
#
# Question 3
# 1 / 1 pts
# For sequential access of a file, what of the following is true?
#
# Read the file from beginning to end, cannot skip ahead
# [ Select ]
# Read any piece of data anywhere you want
# [ Select ]
# Once a piece of data is read, cannot read it again using read()
# [ Select ]
# Data can be read repeatedly in one read() call
# [ Select ]
#
#
#
# Answer 1:
# Correct!
# True
# Answer 2:
# Correct!
# False
# Answer 3:
# Correct!
# True
# Answer 4:
# Correct!
# False
#
# Question 4
# 1 / 1 pts
# When open a file to write to it, we need to pass an argument to the mode parameter, what value should we pass to mode?
# Correct!
#   w
#   r
#   b
#   t
#
# Question 5
# 1 / 1 pts
# A function is defined like below. Which of the following function call generates an error?
#
# def greeting(name, time="Day ", salute='Ms. '):
#     str = "Good " + time + salute + name
#     return str
#
# Note: Passing in arguments means call a function with arguments.
#
#   Call the function by passing in 1 argument
#   Call the function by passing in 3 argument
# Correct!
#   Call the function by passing in 0 argument
#   Call the function by passing in 2 argument
#
# Question 6
# 1 / 1 pts
# A function is defined like below. Which of the following function call will lead to an execution error?
#
# def greeting(name, time="Day ", salute='Ms. '):
#     str = "Good " + time + salute + name
#     return str
# Correct!
#   greeting(salute='Mr. ', time='Evening ')
#   greeting('John', salute='Mr. ')
#   greeting("Mary")
#   greeting('John', 'Mr. ')
#
# Question 7
# 1 / 1 pts
# A function is defined like below. Which of the following function call will lead to most senseless result (even though the code would not err out)?
#
# def greeting(name, time="Day ", salute='Ms. '):
#     str = "Good " + time + salute + name
#     return str
#   greeting('John', 'Evening ', 'Mr. ')
#   greeting('John', salute='Mr. ')
# Correct!
#   greeting('John', 'Mr. ')
#   greeting("Mary")

# %% [markdown]
# ### Checkpoint5
#
# Question 1
# 1 / 1 pts
# If you have a string
#
# string = 'I love Python'
# Which of the following will result in an error?
#
#   string[:]
# Correct!
#   string[44]
#   string[-4]
#   string[2:44]
#
# Question 2
# 1 / 1 pts
# To determine the length of a string that’s in a variable named city, you can use this code:
#   city.len()
# Correct!
#   len(city)
#   length(city)
#   city.length()
#
# Question 3
# 1 / 1 pts
# To access the first three characters in a string that’s stored in a variable named message, you can use which of the following statement? Mark True if a statement can be used.
#
# first_three = message[0:3]
# [ Select ]
# first_three = message[1:3]
# [ Select ]
# first_three = message.slice(0:2) False
# first_three = message[:3] True
#
# Answer 1:
# Correct!
# True
# Answer 2:
# Correct!
# False
# Answer 3:
# Correct!
# False
# Answer 4:
# Correct!
# True
#
# Question 4
# 1 / 1 pts
# You have the following code:
#
# your_age = input("enter your age: ")
# friend_age = input("enter your friend's age: ")
# if your_age > friend_age:
#     print('You are older than your friend')
# elif your_age < friend_age:
#     print('You are younger than your friend')
# else:
#     print("You two are of the same age")
# If your age is entered as 9 and your friend's age is entered as 11, what would be the output of this program and why?
#
#   There is going to be an error because Python cannot compare two strings
#   Output: You are younger than your friend. This is expected and the program works fine.
# Correct!
#   Output:  You are older than your friend. This not right because Python compare "9" and "11" as two strings. Only the first character is compared in this case and "9" comes after "1" in Unicode values.
#   Output: You are older than your friend. This is not right because Python cannot compare two strings
#
# Question 5
# 1 / 1 pts
# You have the following code:
#
# str1 = 'I love Python'
# str1.replace('I', 'We')
# print(str1)
# What do you get and why.
#
#   I love Python because the replace() method was incorrectly called and did not work
#   We love Python because the replace() method worked correctly and changed the string
# Correct!
#   I love Python because the replace does not change the string stored in variable str1. String has a property of immutable
#
# Question 6
# 1 / 1 pts
# For the following code
#
# future_day = date(3089, 1, 1)
# future_day.weekday()
# You get 1 as the returned value. Which week day is this future day?
# Correct!
#   Tuesday
#   Friday
#   Sunday
#   Monday
#
# Question 7
# 1 / 1 pts
# Match the object and its description
# Correct!
# Date
# Contains the date information including year, month, day, etc. Does not have hour, minute or second, etc.
# Correct!
# Time
# Contains the time information including hour, minute or second, etc. Does not have information such as year, month, day, etc.
# Correct!
# DateTime
# Contains complete date and time information including year, month, day, hour, minute and second etc.
# Correct!
# TimeDelta
# Contains time interval or duration information. The difference between two dates or times
#
# Question 8
# 1 / 1 pts
# I can use
#
# from datetime import date, time, datetime, timedelta
# dt_now = datetime.now()
# to get the current time. What of the following is correct?
#
#   I can get the datetime of one week from now by doing dt_now + 7
# Correct!
#   I can get the datetime of 5 hours before now by doing dt_now + timedelta(hours=-5)
#   I can get the datetime of three days prior by doing dt_now - 3
#   I can get the datetime of one month from now by doing dt_now + timedelta(month=1)
#
# Question 9
# 1 / 1 pts
# We use strptime() to convert string to a datetime object. Which of the following code does the proper conversion for the following date string:
#
# from datetime import date, time, datetime, timedelta
# date_string = 'Wednesday, December 30, 2020 10:33'
#   date_string.strptime('%A, %B %d, %Y %M:%S')
#   datetime.strptime(date_string, '%A %B %d %Y %H:%M')
# Correct!
#   datetime.strptime(date_string, '%A, %B %d, %Y %H:%M')
#   datetime.strptime(date_string, '%A, %B %d, %Y %M:%S')
#
# Question 10
# 1 / 1 pts
# You have a string
#
# str = "IU has over 40000 students";
# str.isdigit()
# str.isalpha()
# str.isalnum()
# Which of the above method will return true and why?
#   str.isdigit() will return true since the string contains number 40000
#   str.isalnum() will return true since the string contains both alphabetic characters and numbers
# Correct!
#   none of the above will return true since it contains a combination of alphabetic characters, numbers and spaces
#   str.isalpha() will return true since it contains mostly alphabetic characters

# %% [markdown]
# ### Checkpoint 6
#
# Question 1
# 1 / 1 pts
# If you have the following code
#
# fruit_list = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
#
# Which of the following code will allow you to retrieve kiwi and melon in a list? (Select ALL that works).
#
# Correct!
#   fruit_list[4:6]
# Correct!
#   fruit_list[-3:-1]
#   fruit_list[-4:-2]
#   fruit_list[5:7]
#
# Question 2
# 1 / 1 pts
# Given list1 = ["H", "e", "l", "l", "o"] what does "&".join(list1) do?
#   Return a string: "Hello&"
#   Return a list: ["&", "H", "e", "l", "l", "o"]
# Correct!
#   Return a string: "H&e&l&l&o"
#   Return a string: "&Hello"
#
# Question 3
# 1 / 1 pts
# If you have the following code
#
# fruit_list = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
#
# Which of the following code will allow you retrieve orange? (Select ALL that works). It is recommended that you use Jupyter notebook to try it out before submitting your answer.
#
#   fruit_list[4]
# Correct!
#   fruit_list[-4]
#   fruit_list.orange
#   fruit_list(3) (parenthesis used here)
# Correct!
#   fruit_list[3]
#
# Question 4
# 1 / 1 pts
# What will be the output of following code?
# list2 = ["one", "two", [1, 2, 3, 4], [1.5, True, "23"]]
# list2[3][1] = 9
# print(list2)
#   ["one", "two", [1, 2, 3, 4], [9]]
#   ["one", "two", [1, 2, 9, 4], [1.5, True, "23"]]
# Correct!
#   ["one", "two", [1, 2, 3, 4], [1.5, 9, "23"]]
#   Error
#
# Question 5
# 1 / 1 pts
# For the following list:
#
# lst = [9, 18, -1, -31, 15]
# create a list that identifies each element as positive or negative. Which of the following is correct? (You can ignore the possibility of having 0 in the list.)
#
#   ["positive" if ele > 0 for ele in lst else 'negative' ]
# Correct!
#   ["positive" if ele > 0 else 'negative' for ele in lst]
#   [if ele > 0 "positive" else 'negative' for ele in lst]
#   [for ele in lst "positive" if ele > 0 else 'negative' ]
#
# Question 6
# 1 / 1 pts
# You have the following dictionary
#
# student = {
#   "name": "Emma",
#   "class": "S364",
#   "grade": "A"
# }
# Select ALL CORRECT ways to remove key "grade" and its value
# Correct!
#   del student[“grade”]
#   student.remove('grade')
#   student['grade']=None
# Correct!
#   student.pop('grade')
#
# Question 7
# 1 / 1 pts
# You have a dictionary:
# department= {
#    "class":{
#       "student":{
#          "name":"Ashley",
#          "grade":{
#             "A100":"A-",
#             "K201":"B+"
#          }
#       }
#    }
# }
# Which of the following can get the grade of K201
# Correct!
#   department['class']['student']['grade']['K201']
#   department['class']['student']['name']['grade']['K201']
#   department['class']['student']['Ashley']['grade']['K201']
#   department['class']['student']['Ashley']['K201']
#
# Question 8
# 0 / 1 pts
# You have the following 2 sets
#
# set1 = {10, 20, 30, 40, 50}
# set2 = {30, 40, 50, 60, 70}
# Which of the following code will get you a set of all values found in both set1 and set2? Select ALL correct ones
#
# Correct Answer
#   set1|set2
# Correct Answer
#   set1.union(set2)
# You Answered
#   set1&set2
#   set1+set2
#
# Question 9
# 1 / 1 pts
# Match the following terms to their respective definitions:
# Correct!
# dictionary
# A mapping from a set of keys to their corresponding values.
# Correct!
# item
# Another name for a key-value pair.
# Correct!
# key
# An object that appears in a dictionary as the first part of a key-value pair.
# Correct!
# value
# An object that appears in a dictionary as the second part of a key-value pair. This is more specific than our previous use of the word “value”.
# Correct!
# Set
# A collection of unordered items with unique value
# Correct!
# List
# A mutable data structure with a sequence of elements
# Correct!
# Tuple
# A immutable data structure with a sequence of elements
#
# Question 10
# 1 / 1 pts
# You have the following 2 sets
#
# set1 = {10, 20, 30, 40, 50}
# set2 = {30, 40, 50, 60, 70}
# Which of the following code will get you a set of all values in set1 but not in set2 and in set 2 but not in set1? In other words, find a set of values that are not in both set1 and set2. Select ALL correct ones
#
#   set1.union(set2)
#   set1.intersection(set2)
#   set1.difference(set2)
# Correct!
#   set1.symmetric_difference(set2)

# %%
fruit = "peach"
index = 0
while index < len(fruit):
    letter = fruit[index]
    print(letter)
    index = index + 1
# Out:
# p
# e
# a
# c
# h

# %%
x = "Go ahead, make my day"


print(x[15:len(x)])

print(x[16::])

print(x[x.find('my'):])

print(x[-6:100])
# Out:
# my day
# y day
# my day
# my day

# %%
word = 'banana'

if word = 'Banana':
    print('We have a match.')
# Out:
#   Cell In[4], line 3
#     if word = 'Banana':
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
hi = ' Hello, World! '
hi = hi.strip()
print(hi)
# Out:
# Hello, World!

# %%
word = 'apple'
print(word.upper())
# Out:
# APPLE

# %%
students = [
    ["Lizzy", 73, "C"], 
    ["Mike", 98, "A"], 
    ["Joel", 88, "B+"], 
    ["Anne", 93, "A"]
]
students.sort()
students.reverse()
print(students)
# Out:
# [['Mike', 98, 'A'], ['Lizzy', 73, 'C'], ['Joel', 88, 'B+'], ['Anne', 93, 'A']]

# %%
x = [3,2,1,4,5]
x.sort()
print(x)
# Out:
# [1, 2, 3]

# %%
x = (1,1,2,3)

x.count(1)
# Out:
# 2

# %%
x = "I love data analytics"

output = x.split()

print(output)
# Out:
# ['I', 'love', 'data', 'analytics']

# %%
trees = {"maple": "ash", "oak": "cherry", "banana": ["avocado", "pear"]}

# %%
dict.items(trees).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dict.items(trees).count()
#
# NameError: name 'trees' is not defined

# %%
dictionary = {1:[0, 1, 2], 3:(92, 12), 'a':['er', 'Julia', 'Star Wars'] }

# %%
# dictionary['a'][-1]

dictionary['a'][2]
# Out:
# 'Star Wars'

# %%
s1 = {1, 3, 5, 10, 12}

# %%
s1[-2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s1[-2]
#
# TypeError: 'set' object is not subscriptable

# %%
from datetime import date

this_day = date(2018, 2, 8)
this_day = this_day.strftime("%B %d, %Y")
print("Today is:", this_day)
# Out:
# Today is: February 08, 2018

# %%
# create a regex expression that will get all 5 letter words from a text
import re
text = "I love data analytics"
pattern = r'\b\w{5}\b'

# %%
print(type(5%3))
print(type(5//2))
print(type(4**0.5))
print(type(5/3))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
today = input("Enter today's date:")
print(type(today))
# Out:
# <class 'str'>

# %%
_7 = 10

print(_7)
# Out:
# 10
